# %%
import pandas as pd
dfjson = pd.read_json("needsstring.json")

# %%
dfjson
# Out:
#      Postcode        Suburb  index
# 0         810          Tiwi      0
# 1         812       Leanyer      1
# 2         820         Parap      2
# 3         829     Pinelands      3
# 4         830          Gray      4
# ..        ...           ...    ...
# 903      6990      GOSNELLS    903
# 904      7008  Lenah Valley    904
# 905      7172        Nugent    905
# 906      7173        Sorell    906
# 907      7277        Legana    907
#
# [908 rows x 3 columns]

# %%
allaustralia = pd.read_csv('australian_postcodes.csv')

# %%
fs = pd.read_excel('Nursevisitssince2014.xlsx', sheet_name="NurseCARE visit postcode report")

# %%
fs
# Out:
#       Aesir_Person_Unique_ID_Number Date_of_entry             Suburb State  \
# 0                                 2    2014-03-27          Punchbowl   NSW
# 1                                 5    2014-03-02     Toorak Gardens    SA
# 2                                 6    2014-05-03           Wundowie    WA
# 3                                 8    2014-04-08          Vincentia   NSW
# 4                                12    2014-04-16      Alice Springs    NT
# ...                             ...           ...                ...   ...
# 2204                           3147    2021-09-09          Mona Vale   NSW
# 2205                           3148    2021-09-09              Leura   NSW
# 2206                           3149    2021-09-10             Camira   QLD
# 2207                           3150    2021-09-10             Petrie   QLD
# 2208                           3151    2021-09-10  Augustine Heights   QLD
#
#      PostCode
# 0        2196
# 1        5065
# 2        6560
# ...

# %%
newnew = dfjson.rename(columns={"Postcode": "postcode"})
newnew
# Out:
#      postcode        Suburb  index
# 0         810          Tiwi      0
# 1         812       Leanyer      1
# 2         820         Parap      2
# 3         829     Pinelands      3
# 4         830          Gray      4
# ..        ...           ...    ...
# 903      6990      GOSNELLS    903
# 904      7008  Lenah Valley    904
# 905      7172        Nugent    905
# 906      7173        Sorell    906
# 907      7277        Legana    907
#
# [908 rows x 3 columns]

# %%
allaustralia
# Out:
#           id  postcode                        locality state        long  \
# 0        230       200                             ANU   ACT  149.119000
# 1      21820       200  Australian National University   ACT  149.118900
# 2        232       800                          DARWIN    NT  130.836680
# 3        233       801                          DARWIN    NT  130.836680
# 4        234       804                           PARAP    NT  130.873315
# ...      ...       ...                             ...   ...         ...
# 18438  11186      9013                        BRISBANE   QLD  152.823141
# 18439  11187      9015                        BRISBANE   QLD  152.823141
# 18440  11196      9464                    NORTHGATE MC   QLD  153.074982
# 18441  11197      9726                   GOLD COAST MC   QLD  153.412197
# 18442  23878      9999                      NORTH POLE   VIC  144.956776
#
#              lat                    dc           type  \
# ...

# %%
dfout= newnew.merge(allaustralia,on='postcode', how='left')
dfout.head(10)
# Out:
#    postcode Suburb  index       id       locality state        long  \
# 0       810   Tiwi      0    235.0          ALAWA    NT  130.866242
# 1       810   Tiwi      0    236.0        BRINKIN    NT  130.866242
# 2       810   Tiwi      0    237.0      CASUARINA    NT  130.866242
# 3       810   Tiwi      0  19972.0  COCONUT GROVE    NT  130.850237
# 4       810   Tiwi      0    239.0        JINGILI    NT  130.866242
# 5       810   Tiwi      0    240.0      LEE POINT    NT  130.866242
# 6       810   Tiwi      0  19973.0          LYONS    NT  130.888515
# 7       810   Tiwi      0    241.0        MILLNER    NT  130.866242
# 8       810   Tiwi      0    242.0           MOIL    NT  130.866242
# 9       810   Tiwi      0  19974.0       MUIRHEAD    NT  130.895903
#
#          lat                            dc           type  ...  \
# 0 -12.381806                           NaN            NaN  ...
# 1 -12.381806                           NaN            NaN  ...
# ...

# %%
xx= dfout.drop_duplicates(subset = ['postcode']) 
xx
# Out:
#       postcode        Suburb  index       id       locality state        long  \
# 0          810          Tiwi      0    235.0          ALAWA    NT  130.866242
# 16         812       Leanyer      1  19975.0          ANULA    NT  130.890470
# 27         820         Parap      2    262.0          BAGOT    NT  130.873315
# 47         829     Pinelands      3  20056.0      PINELANDS    NT  130.959767
# 48         830          Gray      4  20057.0         ARCHER    NT  130.958076
# ...        ...           ...    ...      ...            ...   ...         ...
# 7426      6990      GOSNELLS    903  10413.0       GOSNELLS    WA  116.008461
# 7427      7008  Lenah Valley    904  10436.0  CORNELIAN BAY   TAS  147.293268
# 7430      7172        Nugent    905  10129.0         NUGENT   TAS  147.631695
# 7435      7173        Sorell    906  10134.0        CARLTON   TAS  147.630737
# 7442      7277        Legana    907  11551.0    BRIDGENORTH   TAS  146.996977
#
# ...

# %%
data = [xx["index"], xx["postcode"], xx["Suburb"],xx["state"],xx["long"],xx["lat"]]

headers = ["index","postcode", "Suburb","state","long","lat"]

df3 = pd.concat(data, axis=1, keys=headers)
df3
# Out:
#       index  postcode        Suburb state        long        lat
# 0         0       810          Tiwi    NT  130.866242 -12.381806
# 16        1       812       Leanyer    NT  130.890470 -12.391249
# 27        2       820         Parap    NT  130.873315 -12.428017
# 47        3       829     Pinelands    NT  130.959767 -12.457633
# 48        4       830          Gray    NT  130.958076 -12.521396
# ...     ...       ...           ...   ...         ...        ...
# 7426    903      6990      GOSNELLS    WA  116.008461 -32.060407
# 7427    904      7008  Lenah Valley   TAS  147.293268 -42.861932
# 7430    905      7172        Nugent   TAS  147.631695 -42.730285
# 7435    906      7173        Sorell   TAS  147.630737 -42.823649
# 7442    907      7277        Legana   TAS  146.996977 -41.366416
#
# [908 rows x 6 columns]

# %%
data1 = [xx["postcode"], xx["Suburb"],xx["state"],xx["long"],xx["lat"]]

headers = ["postcode", "Suburb","state","long","lat"]

dfclean = pd.concat(data1, axis=1, keys=headers)
dfclean
# Out:
#       postcode        Suburb state        long        lat
# 0          810          Tiwi    NT  130.866242 -12.381806
# 16         812       Leanyer    NT  130.890470 -12.391249
# 27         820         Parap    NT  130.873315 -12.428017
# 47         829     Pinelands    NT  130.959767 -12.457633
# 48         830          Gray    NT  130.958076 -12.521396
# ...        ...           ...   ...         ...        ...
# 7426      6990      GOSNELLS    WA  116.008461 -32.060407
# 7427      7008  Lenah Valley   TAS  147.293268 -42.861932
# 7430      7172        Nugent   TAS  147.631695 -42.730285
# 7435      7173        Sorell   TAS  147.630737 -42.823649
# 7442      7277        Legana   TAS  146.996977 -41.366416
#
# [908 rows x 5 columns]

# %%
compression_opts = dict(method='zip',
                        archive_name='dfclean.csv')  
dfclean.to_csv('dfclean.zip', index=False,
          compression=compression_opts)

# %%
dfclean.reset_index().to_json(r'PleName.json', orient='records')
# Out:
# None

# %%
aa.to_json(r'PleName.json')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-74-b6d1ed7c8837> in <module>
# ----> 1 aa.to_json(r'PleName.json')
#
# NameError: name 'aa' is not defined

# %%
allaustralia
# Out:
#           id  postcode                        locality state        long  \
# 0        230       200                             ANU   ACT  149.119000
# 1      21820       200  Australian National University   ACT  149.118900
# 2        232       800                          DARWIN    NT  130.836680
# 3        233       801                          DARWIN    NT  130.836680
# 4        234       804                           PARAP    NT  130.873315
# ...      ...       ...                             ...   ...         ...
# 18438  11186      9013                        BRISBANE   QLD  152.823141
# 18439  11187      9015                        BRISBANE   QLD  152.823141
# 18440  11196      9464                    NORTHGATE MC   QLD  153.074982
# 18441  11197      9726                   GOLD COAST MC   QLD  153.412197
# 18442  23878      9999                      NORTH POLE   VIC  144.956776
#
#              lat                    dc           type  \
# ...

# %%
dfjson1
# Out:
#      810      812    820        829   830  832  836  837  838  851   ... 6537  \
# 0    Tiwi      NaN    NaN        NaN   NaN  NaN  NaN  NaN  NaN  NaN  ...  NaN
# 1     NaN  Leanyer    NaN        NaN   NaN  NaN  NaN  NaN  NaN  NaN  ...  NaN
# 2     NaN      NaN  Parap        NaN   NaN  NaN  NaN  NaN  NaN  NaN  ...  NaN
# 3     NaN      NaN    NaN  Pinelands   NaN  NaN  NaN  NaN  NaN  NaN  ...  NaN
# 4     NaN      NaN    NaN        NaN  Gray  NaN  NaN  NaN  NaN  NaN  ...  NaN
# ..    ...      ...    ...        ...   ...  ...  ...  ...  ...  ...  ...  ...
# 903   NaN      NaN    NaN        NaN   NaN  NaN  NaN  NaN  NaN  NaN  ...  NaN
# 904   NaN      NaN    NaN        NaN   NaN  NaN  NaN  NaN  NaN  NaN  ...  NaN
# 905   NaN      NaN    NaN        NaN   NaN  NaN  NaN  NaN  NaN  NaN  ...  NaN
# 906   NaN      NaN    NaN        NaN   NaN  NaN  NaN  NaN  NaN  NaN  ...  NaN
# 907   NaN      NaN    NaN        NaN   NaN  NaN  NaN  NaN  NaN  NaN  ...  NaN
#
# ...

# %%
df1=pd.read_csv("output.csv")
df1.head(10)
# Out:
#     810      812    820        829   830       832         836       837  \
# 0  Tiwi      NaN    NaN        NaN   NaN       NaN         NaN       NaN
# 1   NaN  Leanyer    NaN        NaN   NaN       NaN         NaN       NaN
# 2   NaN      NaN  Parap        NaN   NaN       NaN         NaN       NaN
# 3   NaN      NaN    NaN  Pinelands   NaN       NaN         NaN       NaN
# 4   NaN      NaN    NaN        NaN  Gray       NaN         NaN       NaN
# 5   NaN      NaN    NaN        NaN   NaN  Johnston         NaN       NaN
# 6   NaN      NaN    NaN        NaN   NaN       NaN  Humpty Doo       NaN
# 7   NaN      NaN    NaN        NaN   NaN       NaN         NaN  Noonamah
# 8   NaN      NaN    NaN        NaN   NaN       NaN         NaN       NaN
# 9   NaN      NaN    NaN        NaN   NaN       NaN         NaN       NaN
#
#              838        851  ... 6537 6560 6562 6566 6743 6990 7008 7172 7173  \
# 0            NaN        NaN  ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# ...
